# %%
'''
NAME: Hui Kong

Astronomy 8824: Problem Set 2
Part I: Kepler Potential
'''

import plot as plt

# %%
#orbit plot
plt.orbit_plot_all(0.2)
# Out:
# True

# %%
plt.orbit_plot_all(0.5)
# Out:
# True

# %%
plt.orbit_plot_all(1)
# Out:
# True

# %%
#energy plot
plt.energy_check(0.2)
plt.energy_check(0.5)
plt.energy_check(1)
# Out:
# True

# %%
'''
I can also make angular momentum plot, as angular momentum is also theoratically conserved
'''
#angular momentum plot
plt.angular_momentum_check(0.2)
plt.angular_momentum_check(0.5)
plt.angular_momentum_check(1)
# Out:
# True

# %%
'''
comment:
1. from the above plots, we can see that time step has a big impact on both leap frog method
and euler method. 
2. leap frog method is more precise than euler method
'''
# Out:
# '\ncomment:\n1. from the above plots, we can see that time step has a big impact on both leap frog method\nand euler method. \n2. leap frog method is more precise than euler method\n'

# %%
'''
Part II: Harmonic Oscillator Potential
'''
#orbit plot for q=1.0,0.9,0.6, ydot=1 & 0.5
reload(plt)
plt.orbit_plot_ho(1)
plt.orbit_plot_ho(0.5)
# Out:
# True

# %%
'''
For the case q = 0.9, y ̇ = 0.5, compare the energy conservation of 
the Euler and leapfrog methods for ∆t = 0.01, 0.001, and 0.0001. 
'''
reload(plt)
plt.orbit_plot_ho_compare(0.01)
plt.orbit_plot_ho_compare(0.001)
plt.orbit_plot_ho_compare(0.0001)
# Out:
# True

# %%
'''
comment:
euler method is always less precise than leap frog for harmonic oscillators
'''
# Out:
# '\ncomment:\neuler method is not precise at low \xe2\x88\x86t for harmonic oscillators\n'

# %%
'''
Part III: Planet and Moon
'''
#ym_dot = 2.3484
import matplotlib.pyplot as pt
import numpy as np
pt.clf()
moon = np.loadtxt('./output/Q3/moon_m0.01_x1.05_ydot2.3484.txt').transpose()
star = np.loadtxt('./output/Q3/star_m1_x0_ydot0.txt').transpose()
planet = np.loadtxt('./output/Q3/planet_m0.1_x1_ydot1.txt').transpose()
lgd_star, = pt.plot(star[1],star[2],label='star')
lgd_moon, = pt.plot(moon[1],moon[2],label='moon')
lgd_planet, = pt.plot(planet[1],planet[2],label='planet')
pt.legend(handles = [lgd_star,lgd_moon,lgd_planet])
pt.axis((-3,3,-2,2))
pt.title('orbit')
pt.show()

# %%
'''
Calculate and plot the case with xm = 1.1, again with y ̇p = 1 
and y ̇m chosen to put the moon in a circular orbit about the planet.
'''
#ym_dot=1.953463
pt.clf()
moon = np.loadtxt('./output/Q3/moon_m0.01_x1.1_ydot1.953463.txt').transpose()
star = np.loadtxt('./output/Q3/star_m1_x0_ydot0.txt').transpose()
planet = np.loadtxt('./output/Q3/planet_m0.1_x1_ydot1.txt').transpose()
lgd_star, = pt.plot(star[1],star[2],label='star')
lgd_moon, = pt.plot(moon[1],moon[2],label='moon')
lgd_planet, = pt.plot(planet[1],planet[2],label='planet')
pt.legend(handles = [lgd_star,lgd_moon,lgd_planet])
pt.axis((-3,3,-2,2))
pt.title('orbit')
pt.show()

# %%
'''
Repeat for xm = 1.2.
'''
#ym_dot=1.67419986
pt.clf()
moon = np.loadtxt('./output/Q3/moon_m0.01_x1.2_ydot1.67419986.txt').transpose()
star = np.loadtxt('./output/Q3/star_m1_x0_ydot0.txt').transpose()
planet = np.loadtxt('./output/Q3/planet_m0.1_x1_ydot1.txt').transpose()
lgd_star, = pt.plot(star[1],star[2],label='star')
lgd_moon, = pt.plot(moon[1],moon[2],label='moon')
lgd_planet, = pt.plot(planet[1],planet[2],label='planet')
pt.legend(handles = [lgd_star,lgd_moon,lgd_planet])
pt.axis((-3,3,-2,2))
pt.title('orbit')
pt.show()

# %%
'''
Comment on the results for these three cases.
critical point is xm=1.1, when the force excerted by moon equals to force excerted by star. 
'''

'''
Go back to xm = 1.05, but now set y ̇p = 0.7, 
so the planet is in an elliptical orbit. Compute, plot, comment.
'''
#ym_dot=2.0484
pt.clf()
moon = np.loadtxt('./output/Q3/moon_m0.01_x1.05_ydot2.0484.txt').transpose()
star = np.loadtxt('./output/Q3/star_m1_x0_ydot0.txt').transpose()
planet = np.loadtxt('./output/Q3/planet_m0.1_x1_ydot0.7.txt').transpose()
lgd_star, = pt.plot(star[1],star[2],label='star')
lgd_moon, = pt.plot(moon[1],moon[2],label='moon')
lgd_planet, = pt.plot(planet[1],planet[2],label='planet')
pt.legend(handles = [lgd_star,lgd_moon,lgd_planet])
pt.axis((-3,3,-2,2))
pt.title('orbit')
pt.show()
'''
comment:
'''

# %%
'''
Set y ̇p = 1 but choose the moon velocity relative to the planet to be 0.7vc – i.e., 
70% of the velocity required to put the moon in a circular orbit. Compute, plot, comment.
'''
#v=1.64388
pt.clf()
moon = np.loadtxt('./output/Q3/moon_m0.01_x1.05_ydot1.64388.txt').transpose()
star = np.loadtxt('./output/Q3/star_m1_x0_ydot0.txt').transpose()
planet = np.loadtxt('./output/Q3/planet_m0.1_x1_ydot1.txt').transpose()
lgd_star, = pt.plot(star[1],star[2],label='star')
lgd_moon, = pt.plot(moon[1],moon[2],label='moon')
lgd_planet, = pt.plot(planet[1],planet[2],label='planet')
pt.legend(handles = [lgd_star,lgd_moon,lgd_planet])
pt.axis((-3,3,-2,2))
pt.title('orbit')
pt.show()

# %%
'''
Increase to xm = 1.10 and try a retrograde orbit for the moon (negative y ̇m), 
first at the circular speed, then at 70% of the circular speed. Compute, plot, comment.
'''
